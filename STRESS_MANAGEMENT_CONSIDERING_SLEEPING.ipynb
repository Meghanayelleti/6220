# %% [markdown]
# <a href="https://colab.research.google.com/github/Meghanayelleti/6220/blob/main/STRESS_MANAGEMENT_CONSIDERING_SLEEPING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view, and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing 3 cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [NeMo Voice Swap](https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb): Use Nvidia's NeMo conversational AI Toolkit to swap a voice in an audio fragment with a computer generated one.
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
import pandas as pd
# Replace 'YOUR_RAW_CSV_URL' with the actual URL of your CSV file
csv_url = 'https://raw.githubusercontent.com/Meghanayelleti/6220/main/SaYoPillow.csv'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Meghanayelleti/6220/main/SaYoPillow.csv')

# %%
df.head()
# Out:
#       sr      rr       t      lm      bo    rem   sr.1     hr  sl
# 0  93.80  25.680  91.840  16.600  89.840  99.60  1.840  74.20   3
# 1  91.64  25.104  91.552  15.880  89.552  98.88  1.552  72.76   3
# 2  60.00  20.000  96.000  10.000  95.000  85.00  7.000  60.00   1
# 3  85.76  23.536  90.768  13.920  88.768  96.92  0.768  68.84   3
# 4  48.12  17.248  97.872   6.496  96.248  72.48  8.248  53.12   0

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Select numerical columns
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
data = df[numerical_columns]

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Perform PCA
pca = PCA()
principal_components = pca.fit_transform(scaled_data)

# Calculate explained variance
explained_variance = pca.explained_variance_ratio_

# Plot the scree plot
plt.plot(range(1, len(explained_variance) + 1), explained_variance, marker='o')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
plt.rcParams['figure.figsize'] = (7,5)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Create a pair plot
sns.pairplot(df, diag_kind='kde')  # You can customize the diag_kind parameter based on your preference
plt.show()

# %%
import pandas as pd

# Load data from a CSV file into a DataFrame
df = pd.read_csv('https://raw.githubusercontent.com/Meghanayelleti/6220/main/SaYoPillow.csv')

# Display the columns and head of the DataFrame
print("Columns:")
print(df.columns)

print("\nHead:")
print(df.head())
# Out:
# Columns:
# Index(['sr', 'rr', 't', 'lm', 'bo', 'rem', 'sr.1', 'hr', 'sl'], dtype='object')
#
# Head:
#       sr      rr       t      lm      bo    rem   sr.1     hr  sl
# 0  93.80  25.680  91.840  16.600  89.840  99.60  1.840  74.20   3
# 1  91.64  25.104  91.552  15.880  89.552  98.88  1.552  72.76   3
# 2  60.00  20.000  96.000  10.000  95.000  85.00  7.000  60.00   1
# 3  85.76  23.536  90.768  13.920  88.768  96.92  0.768  68.84   3
# 4  48.12  17.248  97.872   6.496  96.248  72.48  8.248  53.12   0

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [25, 30, 20, 25]

# Create a pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
plt.rcParams['figure.figsize'] = (7,5)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
print("Pandas version: ", pd.__version__)
print("Seaborn version: ", sns.__version__)
# Out:
# Pandas version:  1.5.3
# Seaborn version:  0.12.2

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Meghanayelleti/6220/main/SaYoPillow.csv')
df.head(25)
# Out:
#         sr      rr       t      lm      bo     rem   sr.1     hr  sl
# 0   93.800  25.680  91.840  16.600  89.840   99.60  1.840  74.20   3
# 1   91.640  25.104  91.552  15.880  89.552   98.88  1.552  72.76   3
# 2   60.000  20.000  96.000  10.000  95.000   85.00  7.000  60.00   1
# 3   85.760  23.536  90.768  13.920  88.768   96.92  0.768  68.84   3
# 4   48.120  17.248  97.872   6.496  96.248   72.48  8.248  53.12   0
# 5   56.880  19.376  95.376   9.376  94.064   83.44  6.376  58.44   1
# 6   47.000  16.800  97.200   5.600  95.800   68.00  7.800  52.00   0
# 7   50.000  18.000  99.000   8.000  97.000   80.00  9.000  55.00   0
# 8   45.280  16.112  96.168   4.224  95.112   61.12  7.112  50.28   0
# 9   55.520  19.104  95.104   9.104  93.656   82.76  6.104  57.76   1
# 10  73.440  21.344  93.344  11.344  91.344   91.72  4.016  63.36   2
# 11  59.280  19.856  95.856   9.856  94.784   84.64  6.856  59.64   1
# 12  48.600  17.440  98.160   6.880  96.440   74.40  8.440  53.60   0
# ...

# %%
len(df.index)
# Out:
# 630

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sr      630 non-null    float64
#  1   rr      630 non-null    float64
#  2   t       630 non-null    float64
#  3   lm      630 non-null    float64
#  4   bo      630 non-null    float64
#  5   rem     630 non-null    float64
#  6   sr.1    630 non-null    float64
#  7   hr      630 non-null    float64
#  8   sl      630 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 44.4 KB

# %%
print("Number of duplicated rows is: ", df.duplicated().sum())
# Out:
# Number of duplicated rows is:  0

# %%
print("Number of rows with NaNs is: ", df.isna().any(axis=1).sum())
# Out:
# Number of rows with NaNs is:  0

# %%
X = df.drop(columns=['sl'])
X.head(10)
# Out:
#       sr      rr       t      lm      bo    rem   sr.1     hr
# 0  93.80  25.680  91.840  16.600  89.840  99.60  1.840  74.20
# 1  91.64  25.104  91.552  15.880  89.552  98.88  1.552  72.76
# 2  60.00  20.000  96.000  10.000  95.000  85.00  7.000  60.00
# 3  85.76  23.536  90.768  13.920  88.768  96.92  0.768  68.84
# 4  48.12  17.248  97.872   6.496  96.248  72.48  8.248  53.12
# 5  56.88  19.376  95.376   9.376  94.064  83.44  6.376  58.44
# 6  47.00  16.800  97.200   5.600  95.800  68.00  7.800  52.00
# 7  50.00  18.000  99.000   8.000  97.000  80.00  9.000  55.00
# 8  45.28  16.112  96.168   4.224  95.112  61.12  7.112  50.28
# 9  55.52  19.104  95.104   9.104  93.656  82.76  6.104  57.76

# %%
X.describe().transpose()
# Out:
#       count  mean        std   min    25%   50%    75%    max
# sr    630.0  71.6  19.372833  45.0  52.50  70.0  91.25  100.0
# rr    630.0  21.8   3.966111  16.0  18.50  21.0  25.00   30.0
# t     630.0  92.8   3.529690  85.0  90.50  93.0  95.50   99.0
# lm    630.0  11.7   4.299629   4.0   8.50  11.0  15.75   19.0
# bo    630.0  90.9   3.902483  82.0  88.50  91.0  94.25   97.0
# rem   630.0  88.5  11.893747  60.0  81.25  90.0  98.75  105.0
# sr.1  630.0   3.7   3.054572   0.0   0.50   3.5   6.50    9.0
# hr    630.0  64.5   9.915277  50.0  56.25  62.5  72.50   85.0

# %%
Xs = StandardScaler().fit_transform(X)
Xcols = X.columns
X = pd.DataFrame(Xs)
X.columns = Xcols
X.head(10)
# Out:
#          sr        rr         t        lm        bo       rem      sr.1  \
# 0  1.146845  0.979066 -0.272195  1.140539 -0.271838  0.934005 -0.609407
# 1  1.035260  0.833720 -0.353853  0.972949 -0.345696  0.873421 -0.703767
# 2 -0.599252 -0.454206  0.907316 -0.395697  1.051448 -0.294506  1.081206
# 3  0.731501  0.438056 -0.576145  0.516734 -0.546753  0.708498 -0.960635
# 4 -1.212970 -1.148636  1.438095 -1.211299  1.371498 -1.347997  1.490099
# 5 -0.760431 -0.611664  0.730389 -0.540941  0.811410 -0.425772  0.876760
# 6 -1.270828 -1.261683  1.247559 -1.419854  1.256609 -1.724964  1.343317
# 7 -1.115849 -0.958879  1.757924 -0.861223  1.564349 -0.715229  1.736483
# 8 -1.359683 -1.435290  0.954950 -1.740136  1.080170 -2.303879  1.117902
# 9 -0.830688 -0.680299  0.653267 -0.604253  0.706778 -0.482990  0.787642
#
#          hr
# 0  0.979066
# 1  0.833720
# 2 -0.454206
# 3  0.438056
# 4 -1.148636
# 5 -0.611664
# 6 -1.261683
# 7 -0.958879
# 8 -1.435290
# 9 -0.680299

# %%
X.describe().transpose()
# Out:
#       count          mean       std       min       25%       50%       75%  \
# sr    630.0  2.904202e-16  1.000795 -1.374148 -0.986700 -0.082656  1.015113
# rr    630.0 -1.832749e-16  1.000795 -1.463552 -0.832711 -0.201869  0.807477
# t     630.0  8.007704e-16  1.000795 -2.211582 -0.652133  0.056707  0.765548
# lm    630.0  1.719965e-16  1.000795 -1.792275 -0.744842 -0.162934  0.942690
# bo    630.0 -1.452101e-15  1.000795 -2.282411 -0.615482  0.025645  0.859110
# rem   630.0  5.639228e-18  1.000795 -2.398121 -0.610048  0.126217  0.862482
# sr.1  630.0 -5.216286e-17  1.000795 -1.212261 -1.048442 -0.065528  0.917387
# hr    630.0  4.229421e-18  1.000795 -1.463552 -0.832711 -0.201869  0.807477
#
#            max
# sr    1.467135
# rr    2.069159
# t     1.757924
# lm    1.699170
# bo    1.564349
# rem   1.388386
# sr.1  1.736483
# hr    2.069159

# %%
observations = list(df.index)
variables = list(df.columns)

# %%
ax = plt.figure(figsize=(15,10))
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %%
ax = plt.figure(figsize=(15,10))
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax = sns.stripplot(data=X, color=".25")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %%
fig1,ax1 = plt.subplots(figsize=(15,10))
ax = sns.heatmap(X.corr(), cmap='RdYlGn_r', linewidths=0.3, annot=True, cbar=False, square=True)
plt.yticks(rotation=0)
ax.tick_params(labelbottom=False,labeltop=True)
ax.set_xticklabels(ax.get_xticklabels(),rotation=0);

# %%
import numpy as np

# Assuming you have a NumPy array or list representing your target variable 'y'
y = np.array([0, 1, 0, 1, 1, 0, 0, 1, 1])

# Now you can use np.where with 'y'
idx_0 = np.where(y == 0)
idx_1 = np.where(y == 1)

# %%
print(df.columns)
# Out:
# Index(['sr', 'rr', 't', 'lm', 'bo', 'rem', 'sr.1', 'hr', 'sl'], dtype='object')

# %%
print(df.head())
# Out:
#       sr      rr       t      lm      bo    rem   sr.1     hr  sl
# 0  93.80  25.680  91.840  16.600  89.840  99.60  1.840  74.20   3
# 1  91.64  25.104  91.552  15.880  89.552  98.88  1.552  72.76   3
# 2  60.00  20.000  96.000  10.000  95.000  85.00  7.000  60.00   1
# 3  85.76  23.536  90.768  13.920  88.768  96.92  0.768  68.84   3
# 4  48.12  17.248  97.872   6.496  96.248  72.48  8.248  53.12   0

# %%
import pandas as pd

# Load data from a CSV file into a DataFrame
df = pd.read_csv('https://raw.githubusercontent.com/Meghanayelleti/6220/main/SaYoPillow.csv')

# Check column names
print(df.columns)

# Print the head of the DataFrame
print(df.head())

# Access the 'sl_column'
y = df['sl'].values
# Out:
# Index(['sr', 'rr', 't', 'lm', 'bo', 'rem', 'sr.1', 'hr', 'sl'], dtype='object')
#       sr      rr       t      lm      bo    rem   sr.1     hr  sl
# 0  93.80  25.680  91.840  16.600  89.840  99.60  1.840  74.20   3
# 1  91.64  25.104  91.552  15.880  89.552  98.88  1.552  72.76   3
# 2  60.00  20.000  96.000  10.000  95.000  85.00  7.000  60.00   1
# 3  85.76  23.536  90.768  13.920  88.768  96.92  0.768  68.84   3
# 4  48.12  17.248  97.872   6.496  96.248  72.48  8.248  53.12   0

# %%
pca = PCA()
Z = pca.fit_transform(X)


idx_0= np.where(y == 0)
idx_1 = np.where(y == 1)


plt. figure(figsize=(15,10))
plt.scatter(Z[idx_0,1], Z[idx_1,2], c='g', label='1')
plt.scatter(Z[idx_0,1], Z[idx_1,3], c='r', label='1')


plt.legend()
plt.xlabel('Z1')
plt.ylabel('Z2')
# Out:
# Text(0, 0.5, 'Z2')

# %%
A = pca.components_.T
plt. figure(figsize=(8,4))

plt.scatter(A[:,0],A[:,1],c='r')
plt.xlabel('A1')
plt.ylabel('A2')
for label, x, y in zip(variables, A[:, 0], A[:, 1]):
  plt.annotate(label, xy=(x, y), xytext=(-2, 2), textcoords='offset points', ha='right', va='bottom')
A
# Out:
# array([[-3.59031961e-01, -1.93650205e-01, -1.51616563e-02,
#         -2.55599119e-01,  8.75380523e-01, -4.01014679e-02,
#          1.16480275e-02,  4.42578147e-16],
#        [-3.57371760e-01, -2.91870375e-01,  3.51339624e-01,
#         -1.27751345e-01, -2.55050818e-01, -2.85418489e-01,
#         -2.86799381e-02, -7.07106781e-01],
#        [ 3.48196591e-01, -5.07549757e-01, -1.83461645e-01,
#         -2.42061564e-01, -3.06866184e-02,  6.56923880e-02,
#         -7.23631980e-01, -2.49800181e-16],
#        [-3.59763801e-01, -2.76554728e-01,  7.64271416e-02,
#          1.54354425e-01, -1.23164607e-01,  8.64940947e-01,
#          3.35966008e-02, -5.55111512e-16],
#        [ 3.48335197e-01, -4.95934139e-01, -1.69817812e-01,
#         -3.58086293e-01, -8.22099505e-02,  2.69421526e-02,
#          6.84224877e-01, -8.32667268e-17],
#        [-3.49059001e-01, -2.82781603e-01, -7.09536659e-01,
#          4.59509895e-01, -9.66930235e-02, -2.70083485e-01,
# ...

# %%
plt. figure(figsize=(8,4))
plt.scatter(A[:, 0],A[:, 1], marker='o', c=A[:, 2], s=A[:, 3]*500, cmap=plt.get_cmap('Spectral'))
plt.xlabel('A1')
plt.ylabel('A2')
for label, x, y in zip(variables,A[:, 0],A[:, 1]):
  plt.annotate(label,xy=(x, y), xytext=(-20, 20),
      textcoords='offset points', ha='right', va='bottom',
      bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
      arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

# %%
#Eigenvalues
Lambda = pca.explained_variance_

#Scree plot
x = np.arange(len(Lambda)) + 1
plt. figure(figsize=(15,10))
plt.plot(x,Lambda/sum(Lambda), 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
Lambda
# Out:
# array([7.50905794e+00, 3.26465052e-01, 9.82004459e-02, 5.04414906e-02,
#        2.35893398e-02, 3.46029125e-03, 1.50404020e-03, 1.14667028e-31])

# %%
ell = pca.explained_variance_ratio_
ind = np.arange(len(ell))
plt. figure(figsize=(15,10))
plt.bar(ind, ell, align='center', alpha=0.5)
plt.plot(np.cumsum(ell))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
A1 = A[:,0]
A2 = A[:,1]
Z1 = Z[:,0]
Z2 = Z[:,1]

plt. figure(figsize=(15,10))
plt.xlabel('Z1')
plt.ylabel('Z2')
for i in range(len(A1)):
# arrows project features as vectors onto PC axes
  plt.arrow(0, 0, A1[i]*max(Z1), A2[i]*max(Z2), color='k', width=0.0005, head_width=0.0025)
  plt.text(A1[i]*max(Z1)*1.2, A2[i]*max(Z2)*1.2,variables[i], color='k')

plt.scatter(Z[idx_0,1], Z[idx_1,2], c='g', label='1')
plt.scatter(Z[idx_0,1], Z[idx_1,3], c='r', label='1')

plt.legend(loc='upper left')
Z1
Z2
# Out:
# array([-8.78675000e-01, -5.96370360e-01, -8.01056864e-01,  1.72125605e-01,
#        -3.30122326e-01, -3.17488481e-01,  1.18385427e-01, -1.08297462e+00,
#         8.07165189e-01, -1.06702263e-01, -1.77328755e-01, -6.89464160e-01,
#        -5.22339934e-01,  1.04759835e+00, -9.44954440e-02,  3.89265309e-01,
#         3.39668552e-01,  1.09391240e-01,  7.21051294e-01,  6.81950290e-01,
#        -5.43578840e-01, -5.15405756e-01,  1.46661705e-01, -1.25862626e-01,
#        -3.76800084e-01,  1.78479091e-01, -6.28098090e-01,  6.00051527e-01,
#        -1.00414373e+00,  8.22815707e-01, -7.30575676e-01,  1.06647489e+00,
#        -1.53922852e-01, -1.08545089e+00,  1.00594075e+00,  4.66568760e-02,
#        -4.74285532e-01, -2.73759587e-01,  4.70784375e-01, -3.87018839e-01,
#         9.21421499e-01,  5.12911789e-01, -3.46367256e-01, -7.94648212e-01,
#        -1.63242213e-01, -5.00278091e-01,  7.52382999e-01,  2.35907047e-01,
# ...

# %%
# !pip install pca

# %%
from pca import pca
# Initialize and keep all PCs
model = pca()
# Fit transform
out = model.fit_transform(X)
# Out:
# [pca] >Extracting column labels from dataframe.
# [pca] >Extracting row labels from dataframe.
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [8] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [2] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [8] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[2]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]

# %%
out['PC']
# Out:
#           PC1       PC2
# 0   -2.250047 -0.878675
# 1   -2.111753 -0.596370
# 2    1.844494 -0.801057
# 3   -1.735288  0.172126
# 4    3.661345 -0.330122
# ..        ...       ...
# 625  0.203803  0.160748
# 626  3.618319 -0.458267
# 627 -4.010066  0.330290
# 628  1.867121 -0.590271
# 629  0.101487 -0.219588
#
# [630 rows x 2 columns]

# %%
model.scatter(label=True, legend=False)
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# (<Figure size 2500x1500 with 1 Axes>,
#  <AxesSubplot: title={'center': '2 Principal Components explain [99.01%] of the variance'}, xlabel='PC1 (93.7% expl.var)', ylabel='PC2 (4.07% expl.var)'>)

# %%
A = out['loadings'].T
A
# Out:
#            PC1       PC2
# sr   -0.359032 -0.193650
# rr   -0.357372 -0.291870
# t     0.348197 -0.507550
# lm   -0.359764 -0.276555
# bo    0.348335 -0.495934
# rem  -0.349059 -0.282782
# sr.1  0.349022 -0.363480
# hr   -0.357372 -0.291870

# %%
sns.scatterplot(data=A, x="PC1", y="PC2")
plt.xlabel('A1')
plt.ylabel('A2')
for i in range(A.shape[0]):
 plt.text(x=A.PC1[i]+0.02,y=A.PC2[i]+0.02, s=variables[i],
          fontdict=dict(color='red',size=10),
          bbox=dict(facecolor='yellow',alpha=0.5))

# %%
VR = out['variance_ratio']
x = np.arange(len(VR)) + 1
plt.plot(x, VR, 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
plt.show()

# %%
model.plot();

# %%
model.biplot(label=False, legend=False, color_arrow='k')
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
# (<Figure size 2500x1500 with 1 Axes>,
#  <AxesSubplot: title={'center': '2 Principal Components explain [99.01%] of the variance'}, xlabel='PC1 (93.7% expl.var)', ylabel='PC2 (4.07% expl.var)'>)

# %%
# !pip install pca

# %%
# !pip install pycaret

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
plt.rcParams['figure.figsize'] = (7,5)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
print("Pandas version: ", pd.__version__)
print("Seaborn version: ", sns.__version__)
# Out:
# Pandas version:  1.5.3
# Seaborn version:  0.12.2

# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %%
import pandas as pd
# Replace 'YOUR_RAW_CSV_URL' with the actual URL of your CSV file
csv_url = 'https://raw.githubusercontent.com/Meghanayelleti/6220/main/SaYoPillow.csv'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Meghanayelleti/6220/main/SaYoPillow.csv')

# %%
data = df.sample(frac=0.9, random_state=786)
data_unseen = df.drop(data.index)
#dr = df.drop(columns=['id'])

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (567, 9)
# Unseen Data For Predictions: (63, 9)

# %%
from pycaret.classification import *
clf = setup(data=data, target='sl', train_size=0.7, session_id=123)
# Out:
# <style type="text/css">
# #T_13a6e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_13a6e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13a6e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_13a6e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13a6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13a6e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_13a6e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_13a6e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13a6e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_13a6e_row1_col1" class="data row1 col1" >sl</td>
#     </tr>
#     <tr>
#       <th id="T_13a6e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#show the best model and their statistics
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_c3bee th {
#   text-align: left;
# }
# ...

# %%
best_model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_564b5_row10_col0, #T_564b5_row10_col1, #T_564b5_row10_col2, #T_564b5_row10_col3, #T_564b5_row10_col4, #T_564b5_row10_col5, #T_564b5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_564b5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_564b5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_564b5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_564b5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_564b5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_564b5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_564b5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_564b5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_lr=tune_model(lr)
# Out:
# <style type="text/css">
# #T_85175_row10_col0, #T_85175_row10_col1, #T_85175_row10_col2, #T_85175_row10_col3, #T_85175_row10_col4, #T_85175_row10_col5, #T_85175_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_85175" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85175_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_85175_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_85175_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_85175_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_85175_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_85175_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_85175_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_lr
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
evaluate_model(tuned_lr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
knn = create_model('knn')
# Out:
# <style type="text/css">
# #T_a57da_row10_col0, #T_a57da_row10_col1, #T_a57da_row10_col2, #T_a57da_row10_col3, #T_a57da_row10_col4, #T_a57da_row10_col5, #T_a57da_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a57da" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a57da_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a57da_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a57da_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a57da_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a57da_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a57da_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a57da_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_knn = tune_model(knn)
# Out:
# <style type="text/css">
# #T_368a1_row10_col0, #T_368a1_row10_col1, #T_368a1_row10_col2, #T_368a1_row10_col3, #T_368a1_row10_col4, #T_368a1_row10_col5, #T_368a1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_368a1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_368a1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_368a1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_368a1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_368a1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_368a1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_368a1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_368a1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
evaluate_model(tuned_knn)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
qda=create_model('qda')
# Out:
# <style type="text/css">
# #T_a58b6_row10_col0, #T_a58b6_row10_col1, #T_a58b6_row10_col2, #T_a58b6_row10_col3, #T_a58b6_row10_col4, #T_a58b6_row10_col5, #T_a58b6_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a58b6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a58b6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a58b6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a58b6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a58b6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a58b6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a58b6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a58b6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_qda=tune_model(qda)
# Out:
# <style type="text/css">
# #T_8d2ea_row10_col0, #T_8d2ea_row10_col1, #T_8d2ea_row10_col2, #T_8d2ea_row10_col3, #T_8d2ea_row10_col4, #T_8d2ea_row10_col5, #T_8d2ea_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8d2ea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d2ea_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8d2ea_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8d2ea_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8d2ea_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8d2ea_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8d2ea_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8d2ea_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_qda
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.96,
#                               store_covariance=False, tol=0.0001)

# %%
evaluate_model(tuned_qda)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# !pip install statsmodels --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 28.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.14.0
#     Uninstalling statsmodels-0.14.0:
#       Successfully uninstalled statsmodels-0.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...

# %%
clf_pca = setup(data=data, target='sl', train_size=0.7, session_id=123, normalize = True, pca = True, pca_components = 3)
# Out:
# <style type="text/css">
# #T_6e2e7_row8_col1, #T_6e2e7_row12_col1, #T_6e2e7_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6e2e7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e2e7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6e2e7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e2e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e2e7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6e2e7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_6e2e7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e2e7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6e2e7_row1_col1" class="data row1 col1" >sl</td>
#     </tr>
#     <tr>
# ...

# %%
#show the best model and their statistics
best_model_pca = compare_models()
# Out:
# <style type="text/css">
# #T_a12f4 th {
#   text-align: left;
# }
# ...

# %%
best_model_pca
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Tune hyperparameters with scikit-learn (default)
tuned_best_model_pca = tune_model(best_model_pca)
# Out:
# <style type="text/css">
# #T_53263_row10_col0, #T_53263_row10_col1, #T_53263_row10_col2, #T_53263_row10_col3, #T_53263_row10_col4, #T_53263_row10_col5, #T_53263_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_53263" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53263_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_53263_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_53263_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_53263_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_53263_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_53263_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_53263_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
evaluate_model(tuned_best_model_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
lr_pca = create_model('lr')
# Out:
# <style type="text/css">
# #T_67596_row10_col0, #T_67596_row10_col1, #T_67596_row10_col2, #T_67596_row10_col3, #T_67596_row10_col4, #T_67596_row10_col5, #T_67596_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_67596" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67596_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_67596_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_67596_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_67596_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_67596_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_67596_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_67596_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_lr_pca = tune_model(lr_pca)
# Out:
# <style type="text/css">
# #T_61cae_row10_col0, #T_61cae_row10_col1, #T_61cae_row10_col2, #T_61cae_row10_col3, #T_61cae_row10_col4, #T_61cae_row10_col5, #T_61cae_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_61cae" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61cae_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_61cae_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_61cae_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_61cae_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_61cae_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_61cae_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_61cae_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_lr_pca
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
evaluate_model(tuned_lr_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
knn_pca = create_model('knn')
# Out:
# <style type="text/css">
# #T_87f5b_row10_col0, #T_87f5b_row10_col1, #T_87f5b_row10_col2, #T_87f5b_row10_col3, #T_87f5b_row10_col4, #T_87f5b_row10_col5, #T_87f5b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_87f5b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87f5b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_87f5b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_87f5b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_87f5b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_87f5b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_87f5b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_87f5b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_knn_pca = tune_model(knn_pca)
# Out:
# <style type="text/css">
# #T_f4ed8_row10_col0, #T_f4ed8_row10_col1, #T_f4ed8_row10_col2, #T_f4ed8_row10_col3, #T_f4ed8_row10_col4, #T_f4ed8_row10_col5, #T_f4ed8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f4ed8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4ed8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f4ed8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f4ed8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f4ed8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f4ed8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f4ed8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f4ed8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_knn_pca
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
evaluate_model(tuned_knn_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
qda_pca = create_model('qda')
# Out:
# <style type="text/css">
# #T_950d4_row10_col0, #T_950d4_row10_col1, #T_950d4_row10_col2, #T_950d4_row10_col3, #T_950d4_row10_col4, #T_950d4_row10_col5, #T_950d4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_950d4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_950d4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_950d4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_950d4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_950d4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_950d4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_950d4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_950d4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_qda_pca = tune_model(qda_pca)
# Out:
# <style type="text/css">
# #T_281f8_row10_col0, #T_281f8_row10_col1, #T_281f8_row10_col2, #T_281f8_row10_col3, #T_281f8_row10_col4, #T_281f8_row10_col5, #T_281f8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_281f8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_281f8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_281f8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_281f8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_281f8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_281f8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_281f8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_281f8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_qda_pca
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %%
evaluate_model(tuned_qda_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
et_pca = create_model('et')
# Out:
# <style type="text/css">
# #T_bb27f_row10_col0, #T_bb27f_row10_col1, #T_bb27f_row10_col2, #T_bb27f_row10_col3, #T_bb27f_row10_col4, #T_bb27f_row10_col5, #T_bb27f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bb27f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb27f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_bb27f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_bb27f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_bb27f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_bb27f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_bb27f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_bb27f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_et_pca = tune_model(et_pca)
# Out:
# <style type="text/css">
# #T_14097_row10_col0, #T_14097_row10_col1, #T_14097_row10_col2, #T_14097_row10_col3, #T_14097_row10_col4, #T_14097_row10_col5, #T_14097_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_14097" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14097_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_14097_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_14097_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_14097_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_14097_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_14097_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_14097_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_et_pca
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      n_estimators=100, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False)

# %%
evaluate_model(tuned_et_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 533.5/533.5 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# !pip install shap

# %%
import shap

# %%
interpret_model(tuned_et_pca, plot='summary')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
interpret_model(tuned_et_pca, plot='reason', observation=32)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# ...

# %%
interpret_model(tuned_et_pca, plot='reason')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# ...
